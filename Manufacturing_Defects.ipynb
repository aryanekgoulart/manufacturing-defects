# %% [markdown]
# # **Contextualização**

# %% [markdown]
# Este dataset contém informações simuladas relacionadas a defeitos de fabricação observados durante os processos de controle de qualidade. Inclui informações como tipo de defeito, data de detecção, localização dentro do produto, nível de gravidade, método de inspeção utilizado e custos de reparo. Este conjunto de dados pode ser usado para analisar padrões de defeitos, melhorar os processos de controle de qualidade e avaliar o impacto dos defeitos na qualidade do produto e nos custos de produção.

# %% [markdown]
# # **Estrutura do dataset**

# %% [markdown]
# *   defect_id: Identificador exclusivo para cada defeito.
# *   product_id: Identificador do produto associado ao defeito.
# *   defect_type: Tipo ou categoria do defeito (por exemplo, cosmético, funcional, estrutural).
# *   defect_description: Descrição do defeito.
# *   defect_date: Data em que o defeito foi detectado.
# *   defect_location: Local dentro do produto onde o defeito foi encontrado (por exemplo, superfície, componente).
# *   gravidade: Nível de gravidade do defeito (por exemplo, menor, moderado, crítico).
# *   inspection_method: Método usado para detectar o defeito (por exemplo, inspeção visual, teste automatizado).
# *   repair_action: Ação tomada para reparar ou resolver o defeito.
# *   repair_cost: Custo incorrido para reparar o defeito (em moeda local).

# %% [markdown]
# # **Preparação do ambiente**

# %% [markdown]
# ## Importação das bibliotecas e carregamento dos dados

# %%
# Manipulação dos dados
import pandas as pd
import numpy as np
import datetime as dt

# Visualização
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# Download latest version
import kagglehub
path = kagglehub.dataset_download("fahmidachowdhury/manufacturing-defects")

df = pd.read_csv(path + "/defects_data.csv")
# Out:
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.12), please consider upgrading to the latest version (0.3.13).
# Downloading from https://www.kaggle.com/api/v1/datasets/download/fahmidachowdhury/manufacturing-defects?dataset_version_number=1...
# 100%|██████████| 13.0k/13.0k [00:00<00:00, 18.1MB/s]
# Extracting files...

# %% [markdown]
# ## Qualidade dos dados

# %%
print(f"Dataset possui {df.shape[0]} linhas e {df.shape[1]} colunas.")
df.info()
# Out:
# Dataset possui 1000 linhas e 8 colunas.
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   defect_id          1000 non-null   int64
#  1   product_id         1000 non-null   int64
#  2   defect_type        1000 non-null   object
#  3   defect_date        1000 non-null   object
#  4   defect_location    1000 non-null   object
#  5   severity           1000 non-null   object
#  6   inspection_method  1000 non-null   object
#  7   repair_cost        1000 non-null   float64
# dtypes: float64(1), int64(2), object(5)
# memory usage: 62.6+ KB

# %%
df.head()
# Out:
#    defect_id  product_id defect_type defect_date defect_location  severity  \
# 0          1          15  Structural    6/6/2024       Component     Minor
# 1          2           6  Functional   4/26/2024       Component     Minor
# 2          3          84  Structural   2/15/2024        Internal     Minor
# 3          4          10  Functional   3/28/2024        Internal  Critical
# 4          5          14    Cosmetic   4/26/2024       Component     Minor
#
#    inspection_method  repair_cost
# 0  Visual Inspection       245.47
# 1  Visual Inspection        26.87
# 2  Automated Testing       835.81
# 3  Automated Testing       444.47
# 4     Manual Testing       823.64

# %% [markdown]
# ## Transformação

# %%
# Conversão de defect_date para datetime

df.defect_date = pd.to_datetime(df.defect_date)
df['defect_month'] = df['defect_date'].dt.strftime('%Y-%m')
df.head()
# Out:
#    defect_id  product_id defect_type defect_date defect_location  severity  \
# 0          1          15  Structural  2024-06-06       Component     Minor
# 1          2           6  Functional  2024-04-26       Component     Minor
# 2          3          84  Structural  2024-02-15        Internal     Minor
# 3          4          10  Functional  2024-03-28        Internal  Critical
# 4          5          14    Cosmetic  2024-04-26       Component     Minor
#
#    inspection_method  repair_cost defect_month
# 0  Visual Inspection       245.47      2024-06
# 1  Visual Inspection        26.87      2024-04
# 2  Automated Testing       835.81      2024-02
# 3  Automated Testing       444.47      2024-03
# 4     Manual Testing       823.64      2024-04

# %%
# Dicionário de renomeação
novos_nomes = {
    'defect_id': 'id_defeito',
    'product_id': 'id_produto',
    'defect_type': 'tipo_defeito',
    'defect_date': 'data_defeito',
    'defect_location': 'local_defeito',
    'severity': 'gravidade',
    'inspection_method': 'metodo_inspecao',
    'repair_cost': 'custo_reparo',
    'defect_month': 'ano_mes'
}
df.rename(columns=novos_nomes, inplace=True)
df.head()
# Out:
#    id_defeito  id_produto tipo_defeito data_defeito local_defeito gravidade  \
# 0           1          15   Structural   2024-06-06     Component     Minor
# 1           2           6   Functional   2024-04-26     Component     Minor
# 2           3          84   Structural   2024-02-15      Internal     Minor
# 3           4          10   Functional   2024-03-28      Internal  Critical
# 4           5          14     Cosmetic   2024-04-26     Component     Minor
#
#      metodo_inspecao  custo_reparo  ano_mes
# 0  Visual Inspection        245.47  2024-06
# 1  Visual Inspection         26.87  2024-04
# 2  Automated Testing        835.81  2024-02
# 3  Automated Testing        444.47  2024-03
# 4     Manual Testing        823.64  2024-04

# %%
# Renomeação dos valores nas colunas categóricas
tipo_defeito = {
    'Cosmetic': 'Cosmético',
    'Functional': 'Funcional',
    'Structural': 'Estrutural'
}
df['tipo_defeito'] = df['tipo_defeito'].replace(tipo_defeito)

local_defeito = {
    'Surface': 'Superfície',
    'Component': 'Componente',
    'Internal': 'Interno'
}
df['local_defeito'] = df['local_defeito'].replace(local_defeito)

gravidade = {
    'Minor': 'Leve',
    'Moderate': 'Moderado',
    'Critical': 'Crítico'
}
df['gravidade'] = df['gravidade'].replace(gravidade)


metodo_inspecao = {
    'Visual Inspection': 'Inspeção Visual',
    'Automated Testing': 'Teste Automatizado',
    'Manual Testing': 'Teste Manual'
}
df['metodo_inspecao'] = df['metodo_inspecao'].replace(metodo_inspecao)
df.head()
# Out:
#    id_defeito  id_produto tipo_defeito data_defeito local_defeito gravidade  \
# 0           1          15   Estrutural   2024-06-06    Componente      Leve
# 1           2           6    Funcional   2024-04-26    Componente      Leve
# 2           3          84   Estrutural   2024-02-15       Interno      Leve
# 3           4          10    Funcional   2024-03-28       Interno   Crítico
# 4           5          14    Cosmético   2024-04-26    Componente      Leve
#
#       metodo_inspecao  custo_reparo  ano_mes
# 0     Inspeção Visual        245.47  2024-06
# 1     Inspeção Visual         26.87  2024-04
# 2  Teste Automatizado        835.81  2024-02
# 3  Teste Automatizado        444.47  2024-03
# 4        Teste Manual        823.64  2024-04

# %% [markdown]
# # **Análise dos Dados**

# %%
id_produto = df.groupby("id_produto").agg(defect_count = ('id_produto', 'count'), total_custo_reparo = ('custo_reparo', 'sum')).sort_values(by = 'defect_count', ascending = False).reset_index()
top_10 = id_produto.sort_values(by = 'defect_count', ascending=False).head(10).copy()
top_10
# Out:
#    id_produto  defect_count  total_custo_reparo
# 0          81            20            11740.64
# 1          63            20             9174.06
# 2          97            19             8405.84
# 3          56            18             9916.30
# 4           4            16             6495.45
# 5          10            16            10084.92
# 6          92            16             7588.84
# 7          74            15             8460.54
# 8           6            15             8733.81
# 9          45            15             9532.36

# %%
custo_reparo_mes = df.groupby('ano_mes').agg(total_custo_reparo = ('custo_reparo', 'sum')).reset_index()
custo_reparo_mes
# Out:
#    ano_mes  total_custo_reparo
# 0  2024-01            95978.43
# 1  2024-02            83259.84
# 2  2024-03            91806.75
# 3  2024-04            76153.46
# 4  2024-05            83841.50
# 5  2024-06            76587.17

# %%
tipo_defeito = df.groupby(['tipo_defeito', 'local_defeito', 'gravidade']).agg(defect_count = ('id_defeito', 'count'), total_custo_reparo = ('custo_reparo', 'sum')).reset_index()
tipo_defeito
# Out:
#    tipo_defeito local_defeito gravidade  defect_count  total_custo_reparo
# 0     Cosmético    Componente   Crítico            34            17182.09
# 1     Cosmético    Componente      Leve            35            22658.33
# 2     Cosmético    Componente  Moderado            28            16576.50
# 3     Cosmético       Interno   Crítico            35            14568.13
# 4     Cosmético       Interno      Leve            32            15787.32
# 5     Cosmético       Interno  Moderado            28            16032.00
# 6     Cosmético    Superfície   Crítico            38            18425.21
# 7     Cosmético    Superfície      Leve            39            19181.07
# 8     Cosmético    Superfície  Moderado            40            18387.07
# 9    Estrutural    Componente   Crítico            30            15837.94
# 10   Estrutural    Componente      Leve            44            22656.89
# 11   Estrutural    Componente  Moderado            38            19004.49
# 12   Estrutural       Interno   Crítico            36            18239.88
# 13   Estrutural       Interno      Leve            44            25146.07
# 14   Estrutural       Interno  Moderado            30            12958.35
# 15   Estrutural    Superfície   Crítico            46            21754.09
# 16   Estrutural    Superfície      Leve            51            25935.06
# 17   Estrutural    Superfície  Moderado            33            15391.08
# 18    Funcional    Componente   Crítico            39            23047.16
# 19    Funcional    Componente      Leve            37            15355.77
# 20    Funcional    Componente  Moderado            41            21378.39
# 21    Funcional       Interno   Crítico            44            22739.99
# 22    Funcional       Interno      Leve            38            19218.50
# 23    Funcional       Interno  Moderado            34            17237.09
# 24    Funcional    Superfície   Crítico            31            16660.76
# 25    Funcional    Superfície      Leve            38            18227.96
# 26    Funcional    Superfície  Moderado            37            18039.96

# %%
fig = px.bar(top_10, x=top_10['id_produto'].astype(str), y='defect_count',
             title='Top 10: Número de Defeitos',
             labels={'x': 'ID Produto', 'defect_count': 'Número de Defeitos'},
             color='defect_count', color_continuous_scale='viridis',
             height=400, width=600)
fig.update_layout(xaxis={'categoryorder':'total descending'})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="84edb048-ee5e-4c5b-8c24-03393e2cb1a0" class="plotly-graph-div" style="height:400px; width:600px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("84edb048-ee5e-4c5b-8c24-03393e2cb1a0")) {                    Plotly.newPlot(                        "84edb048-ee5e-4c5b-8c24-03393e2cb1a0",                        [{"alignmentgroup":"True","hovertemplate":"ID Produto=%{x}\u003cbr\u003eNúmero de Defeitos=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":[20,20,19,18,16,16,16,15,15,15],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["81","63","97","56","4","10","92","74","6","45"],"xaxis":"x","y":[20,20,19,18,16,16,16,15,15,15],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity": ...

# %%
fig = px.area(custo_reparo_mes, x='ano_mes', y='total_custo_reparo',
             title='Custo de Reparo por Ano/Mês',
             labels={'ano_mes': 'Mês/Ano', 'total_custo_reparo': 'Custo'},
             color_discrete_sequence=px.colors.sequential.Viridis,
             height=400, width=600)
fig.update_layout(yaxis={'categoryorder':'total ascending'})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="c97ad8f1-98ff-4abc-8414-c24d7f080dbb" class="plotly-graph-div" style="height:400px; width:600px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c97ad8f1-98ff-4abc-8414-c24d7f080dbb")) {                    Plotly.newPlot(                        "c97ad8f1-98ff-4abc-8414-c24d7f080dbb",                        [{"fillpattern":{"shape":""},"hovertemplate":"Mês\u002fAno=%{x}\u003cbr\u003eCusto=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#440154"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"stackgroup":"1","x":["2024-01","2024-02","2024-03","2024-04","2024-05","2024-06"],"xaxis":"x","y":[95978.43,83259.84,91806.75,76153.46,83841.5,76587.17],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scatter ...

# %%
fig = px.bar(tipo_defeito, x='tipo_defeito', y='defect_count', color='local_defeito',
              title='Tipo de Defeito x Frequência',
              labels={'tipo_defeito': 'Tipo de Defeito', 'defect_count': 'Frequência', 'local_defeito': 'Local do Defeito'},
              height=400, width=600, color_discrete_sequence=px.colors.sequential.Viridis)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="d2a40573-c8a4-4aed-82ad-aa67d53347d1" class="plotly-graph-div" style="height:400px; width:600px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d2a40573-c8a4-4aed-82ad-aa67d53347d1")) {                    Plotly.newPlot(                        "d2a40573-c8a4-4aed-82ad-aa67d53347d1",                        [{"alignmentgroup":"True","hovertemplate":"Local do Defeito=Componente\u003cbr\u003eTipo de Defeito=%{x}\u003cbr\u003eFrequência=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Componente","marker":{"color":"#440154","pattern":{"shape":""}},"name":"Componente","offsetgroup":"Componente","orientation":"v","showlegend":true,"textposition":"auto","x":["Cosmético","Cosmético","Cosmético","Estrutural","Estrutural","Estrutural","Funcional","Funcional","Funcional"],"xaxis":"x","y":[34,35,28,30,44,38,39,37,41],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Local do Defeito=Interno\u003cbr\u003eTipo de Defeito=%{x}\u003cbr\u003eFrequência=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Interno","marker":{"color":"#482878","pattern":{"shape":""}},"name":"Interno","offsetgroup":"Interno","orientation":"v","showlegend":true,"textposition":"auto","x":["Cosmético","Cosmético","Cosmético","Estrutural","Estrutural","Estrutural","Funcional","Funcional","Funcional"],"xaxis":"x","y":[35,32,28,36,44,30,44,38,34],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Local do Defeito=Superfície\u003cbr\u003eTipo de Defeito=%{x}\u003cbr\u003eFrequência=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Superfície","marker":{"color":"#3e4989","pattern":{"shape":""}},"name":"Superfície","offsetgroup":"Superfície","orientation":"v","showlegend":true,"textposition":"auto","x":["Cosmético","Cosmético","Cosmético","Estrutural","Estrutural","Estrutural","Funcional","Funcional","Funcional"],"xaxis":"x","y":[38,39,40,46,51,33,31,38,37],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"] ...

# %%
fig = px.bar(tipo_defeito, x='gravidade', y='defect_count', color='local_defeito',
              title='Severidade x Frequência',
              labels={'gravidade': 'Severidade', 'defect_count': 'Frequência', 'local_defeito': 'Local do Defeito'},
              height=400, width=600, color_discrete_sequence=px.colors.sequential.Viridis)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="e9da42a8-5d58-40b5-b453-80a05d59433e" class="plotly-graph-div" style="height:400px; width:600px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e9da42a8-5d58-40b5-b453-80a05d59433e")) {                    Plotly.newPlot(                        "e9da42a8-5d58-40b5-b453-80a05d59433e",                        [{"alignmentgroup":"True","hovertemplate":"Local do Defeito=Componente\u003cbr\u003eSeveridade=%{x}\u003cbr\u003eFrequência=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Componente","marker":{"color":"#440154","pattern":{"shape":""}},"name":"Componente","offsetgroup":"Componente","orientation":"v","showlegend":true,"textposition":"auto","x":["Crítico","Leve","Moderado","Crítico","Leve","Moderado","Crítico","Leve","Moderado"],"xaxis":"x","y":[34,35,28,30,44,38,39,37,41],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Local do Defeito=Interno\u003cbr\u003eSeveridade=%{x}\u003cbr\u003eFrequência=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Interno","marker":{"color":"#482878","pattern":{"shape":""}},"name":"Interno","offsetgroup":"Interno","orientation":"v","showlegend":true,"textposition":"auto","x":["Crítico","Leve","Moderado","Crítico","Leve","Moderado","Crítico","Leve","Moderado"],"xaxis":"x","y":[35,32,28,36,44,30,44,38,34],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Local do Defeito=Superfície\u003cbr\u003eSeveridade=%{x}\u003cbr\u003eFrequência=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Superfície","marker":{"color":"#3e4989","pattern":{"shape":""}},"name":"Superfície","offsetgroup":"Superfície","orientation":"v","showlegend":true,"textposition":"auto","x":["Crítico","Leve","Moderado","Crítico","Leve","Moderado","Crítico","Leve","Moderado"],"xaxis":"x","y":[38,39,40,46,51,33,31,38,37],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0 ...
